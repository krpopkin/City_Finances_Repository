# %% [markdown]
# <a class="anchor" id="top-of-doc"></a>
# ## Table Of Contents:
# * [Prep](#prep)

# %% [markdown]
# <div class="span5 alert alert-info">
# <B>  Prep: </B> <a class="anchor" id="prep"></a>
# </div>

# %% [markdown]
# <div class="span5 alert alert-success">
# <I> About prep: Identify the directory path, the imports for this notebook, and open the data file</I>
# </div>

# %%
#Directory path
# %cd C:\Users\user\Documents\00_Applications_DataScience\00_After_Springboard\City_Finances
# Out:
# C:\Users\user\Documents\00_Applications_DataScience\00_After_Springboard\City_Finances

# %%
#Imports
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Set options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Open spreadsheet
all_data_df = pd.read_excel('Data/fisc_full_dataset_2016_update.xlsx', sheetname='Dataset')

all_data_df.sample()
# Out:
#       year city_name      id_city  city_population       cpi  rev_total_city  \
# 2122  1979  IN: Gary  152045005.0           157913  3.305882          3230.2
#
#       rev_general_city  intergovt_rev_city  igr_federal_city  igr_state_city  \
# 2122           3158.54             2630.78            976.15         1654.63
#
#       own_source_rev_city  taxes_city  tax_property_city  \
# 2122               527.77      465.95             462.79
#
#       tax_sales_grossrec_city  tax_sales_general_city  \
# 2122                      0.0                     0.0
#
#       tax_sales_selectiv_city  tax_sales_motofuel_city  \
# 2122                      0.0                      0.0
#
#       tax_sales_alcohol_city  tax_sales_tobacco_city  tax_sales_utility_city  \
# 2122                     0.0                     0.0                     0.0
#
#       tax_sales_other_city  tax_income_indiv_city  tax_income_corp_city  \
# 2122                   0.0                    0.0                   0.0
# ...

# %%
#Create dataframe of core and FISC columns
core_df = all_data_df.iloc[:, 0:5]

# %%
rev_and_expense_df = all_data_df.iloc[:,526:]

# %%
fisc_df = core_df.join(rev_and_expense_df)

# %%
fisc_df.sample()
# Out:
#       year     city_name      id_city  city_population       cpi  rev_general  \
# 3922  1979  NY: New York  332031001.0          7178900  3.305882      6697.84
#
#       intergovt_rev  igr_federal  igr_state  own_source_rev   taxes  \
# 3922        2962.82       513.72     2449.1         3735.01  2827.1
#
#       tax_property  tax_sales_grossrec  tax_sales_general  tax_sales_selectiv  \
# 3922       1457.68              663.11             462.96              200.15
#
#       tax_sales_motofuel  tax_sales_alcohol  tax_sales_tobacco  \
# 3922                2.96                0.0              28.54
#
#       tax_sales_utility  tax_sales_other  tax_income_indiv  tax_income_corp  \
# 3922              51.11           117.54            647.37              0.0
#
#       tax_motor_vehicle  tax_other  charges_misc_rev  charges  chg_educ  \
# 3922               13.4      45.55            907.91    676.4     71.79
#
#       chg_higher_ed  chg_school_lunch  chg_hospitals  chg_highways  \
# ...

# %%
#Write out the fisc dataframe to a csv file
out_csv = 'Data/fisc_data_input.csv'

fisc_df.to_csv(out_csv)

# %% [markdown]
# <div class="span5 alert alert-info">
# <B>  EDA: </B> <a class="anchor" id="eda"></a>
#
# </div>

# %% [markdown]
# <div class="span5 alert alert-success">
# <I> EDA: </I> Evaluate the city finance data to identify features that need data cleanup and performs the clean up.  In addition, the data is evaluated to identify what data to not move forward with (i.e. the data goes back to 1977, but only the past 10 years will be used going forward).
# </div>

# %%
#Percent of missing values in each column
count = all_data_df.columns.isnull().sum()

df_missing = pd.DataFrame(all_data_df.isnull().sum())
df_missing = df_missing.reset_index()

df_missing.columns = ['col_name','missing_values_count']

df_missing = df_missing[df_missing.missing_values_count > 0]

df_missing = df_missing.sort_values('missing_values_count',ascending=False)

df_missing
# Out:
#                      col_name  missing_values_count
# 660         districts_in_city                  1455
# 298           chg_sewers_schl                  1375
# 300            chg_other_schl                  1375
# 301     misc_general_rev_schl                  1375
# 302        misc_interest_schl                  1375
# 303      misc_fines_fees_schl                  1375
# 304     misc_spec_assess_schl                  1375
# 305   misc_property_sale_schl                  1375
# 306           misc_other_schl                  1375
# 307          rev_utility_schl                  1375
# 308    rev_utility_water_schl                  1375
# 309     rev_utility_elec_schl                  1375
# 310      rev_utility_gas_schl                  1375
# 311  rev_utility_transit_schl                  1375
# 312     rev_liquor_store_schl                  1375
# 313   rev_empl_retire_tr_schl                  1375
# 314      spending_direct_schl                  1375
# ...

# %% [markdown]
# <div class="span5 alert alert-info">
# <B>  Machine Learning: </B> <a class="anchor" id="machine-learning"></a>
#
# </div>

# %% [markdown]
# <div class="span5 alert alert-success">
# <I> Machine learning: </I> Machine learning will...
# </div>

# %%
# Percentage of missing values in each column
df_missing = pd.DataFrame(df.isnull().sum(), columns = ['Count Missing Values'])
df_missing['% Missing Values'] = df.isnull().sum()/len(df)

df_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-41775d2698a0> in <module>
#       1 # Percentage of missing values in each column
# ----> 2 df_missing = pd.DataFrame(df.isnull().sum(), columns = ['Count Missing Values'])
#       3 df_missing['% Missing Values'] = df.isnull().sum()/len(df)
#       4
#       5 df_missing
#
# NameError: name 'df' is not defined
